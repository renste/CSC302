# %% [markdown]
# <a href="https://colab.research.google.com/github/renste/CSC302/blob/main/CSC_302_Release_Date_and_Total_Spotify_Streams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/CSC 302/Most Streamed Spotify Songs 2024.csv', encoding='latin-1')

# %%
top_20_stream_tracks.loc[:, 'Release Date'] = pd.to_datetime(top_20_stream_tracks['Release Date'])
print(top_20_stream_tracks.head())

plt.figure(figsize=(12, 8))
plt.plot_date(top_20_stream_tracks['Release Date'], top_20_stream_tracks['Spotify Streams'], '-o', color='blue')
plt.title('Total Spotify Streams Over Time for Top 20 Tracks', fontsize=16)
plt.xlabel('Release Date', fontsize=12)
plt.ylabel('Spotify Streams', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
#              Track        Album Name          Artist Release Date  \
# 19       As It Was         As It Was    Harry Styles   2022-03-31
# 14  bathroom floor    bathroom floor  Kids With Buns   2022-10-07
# 3          Flowers  Flowers - Single     Miley Cyrus   2023-01-12
# 15            LALA     LALA - Single     Myke Towers   2023-03-22
# 17          greedy            greedy      Tate McRae   2023-09-14
#
#             ISRC All Time Rank  Track Score Spotify Streams  \
# 19  USSM12200612            20        292.0   3,301,814,535
# 14  NLC242100307            15        301.6         297,185
# 3   USSM12209777             4        444.9   2,031,280,633
# 15  USWL12300002            16        299.9     925,655,569
# 17  USRC12301932            18        293.7   1,258,569,694
#
#    Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# 19                407,119            169,783,402  ...           4,909
# ...
