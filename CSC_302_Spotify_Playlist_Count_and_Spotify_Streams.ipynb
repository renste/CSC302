# %% [markdown]
# <a href="https://colab.research.google.com/github/renste/CSC302/blob/main/CSC_302_Spotify_Playlist_Count_and_Spotify_Streams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/CSC 302/Most Streamed Spotify Songs 2024.csv', encoding='latin-1')

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(
    x='Spotify Playlist Count',
    y='Spotify Streams',
    data=top_20_stream_tracks,
    cmap="Blues",  # Color map for the heatmap
    shade=True,    # Fill the area under the density curves
    thresh=0.05    # Threshold for the density plot
)
# Out:
# <ipython-input-41-72b41d87bbcb>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(
# <Axes: xlabel='Spotify Playlist Count', ylabel='Spotify Streams'>

# %%
plt.title('Density Heatmap of Spotify Playlist Count vs. Spotify Streams', fontsize=14)
plt.xlabel('Spotify Playlist Count', fontsize=12)
plt.ylabel('Spotify Streams', fontsize=12)
plt.grid(True)
plt.show()
