# %% [markdown]
# <a href="https://colab.research.google.com/github/renste/CSC302/blob/main/CSC%20302%20Spotify%20Playlist%20Count%20and%20Spotify%20Streams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/CSC 302/Most Streamed Spotify Songs 2024.csv', encoding='latin-1')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='Spotify Playlist Count',
    y='Spotify Streams',
    data=top_20_stream_tracks,
    hue='Spotify Streams',
    palette='Blues',
    s=100,
    alpha=0.8
)
sns.regplot(
    x='Spotify Playlist Count',
    y='Spotify Streams',
    data=top_20_stream_tracks,
    scatter=False,
    color='black',
    line_kws={"linewidth": 2}
)
plt.title('Scatter Plot with Regression Line: Spotify Playlist Count vs. Spotify Streams', fontsize=16)
plt.xlabel('Spotify Playlist Count', fontsize=12)
plt.ylabel('Spotify Streams', fontsize=12)
plt.grid(True)

plt.show()
