# %% [markdown]
# <a href="https://colab.research.google.com/github/renste/CSC302/blob/main/midterm_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
spotify_data = pd.read_csv('/content/drive/MyDrive/CSC 302/Most Streamed Spotify Songs 2024.csv', encoding='latin1')
spotify_data['Spotify Streams'] = spotify_data['Spotify Streams'].str.replace(',', '').astype(float)
spotify_data['All Time Rank'] = spotify_data['All Time Rank'].str.replace(',', '').astype(int)

# %%
top_10_ranked = spotify_data.nsmallest(10, 'All Time Rank')
plt.figure(figsize=(10, 6))
plt.barh(top_10_ranked['Track'], top_10_ranked['All Time Rank'], color='lightgreen')
plt.xlabel('All Time Rank')
plt.title('Top 10 Songs by All Time Rank on Spotify in 2024')
plt.gca().invert_yaxis()
plt.show()
